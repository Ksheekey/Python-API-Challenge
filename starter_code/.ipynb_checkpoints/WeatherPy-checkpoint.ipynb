# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
lat = []
long = []
temp = []
humidity = []
windspeed = []
city_name = []
clouds = []
country = []
date_date = []

for city in cities:
    url_url = f"http://api.openweathermap.org/data/2.5/weather?&q={city}&appid={weather_api_key}"
    response = requests.get(url_url)
    responsej = response.json()
    time.sleep(.5)
    try:
        lat.append(responsej['coord']['lat'])
        long.append(responsej['coord']['lon'])
        temp.append(responsej['main']['temp'])
        humidity.append(responsej['main']['humidity'])
        windspeed.append(responsej['wind']['speed'])
        city_name.append(responsej['name'])
        country.append(responsej['sys']['country'])
        date_date.append(responsej['dt'])
        clouds.append(responsej['clouds']['all'])
        print(f"getting data from {city}")
    except:
        print(f"{city} not found")
        pass
    #break
    
#print(url_url)
#responsej
# Out:
# getting data from kavieng
# getting data from rikitea
# getting data from vangaindrano
# getting data from jamestown
# getting data from salalah
# getting data from punta arenas
# getting data from aklavik
# getting data from port elizabeth
# getting data from tiksi
# getting data from saint-philippe
# getting data from albany
# getting data from dingle
# getting data from pacific grove
# getting data from dunda
# getting data from tezu
# getting data from dikson
# getting data from chuy
# getting data from qaanaaq
# getting data from mar del plata
# getting data from maketu
# getting data from tasiilaq
# burica not found
# getting data from bluff
# getting data from pevek
# getting data from stafford
# getting data from ponta do sol
# getting data from mataura
# getting data from ushuaia
# getting data from russell
# getting data from byron bay
# taolanaro not found
# getting data from hermanus
# cumaribo not found
# getting data from hobart
# getting data from busselton
# getting data from atar
# getting data from port lincoln
# getting data from boditi
# getting data from katherine
# getting data from noumea
# getting data from gamba
# getting data from chokurdakh
# getting data from romodanovo
# getting data from butaritari
# getting data from bengkulu
# getting data from yashan
# getting data from cherskiy
# getting data from samarai
# getting data from saint cloud
# getting data from eirunepe
# getting data from qalyub
# getting data from unai
# getting data from norman wells
# getting data from souillac
# getting data from kapaa
# getting data from broome
# getting data from carballo
# getting data from esperance
# getting data from sioux lookout
# aflu not found
# barentsburg not found
# getting data from cape town
# getting data from alibag
# getting data from nortelandia
# getting data from thakurgaon
# phan rang not found
# getting data from new norfolk
# getting data from hirtshals
# getting data from mogocha
# getting data from lompoc
# getting data from touros
# getting data from ribeira grande
# getting data from east london
# getting data from gat
# getting data from sisimiut
# getting data from shuyskoye
# getting data from hithadhoo
# getting data from namatanai
# getting data from nove mesto pod smrkem
# getting data from mwene-ditu
# getting data from tarragona
# getting data from port moresby
# getting data from coihaique
# katsiveli not found
# getting data from vila franca do campo
# getting data from lasa
# getting data from varhaug
# getting data from ostrovnoy
# getting data from adelanto
# getting data from puerto baquerizo moreno
# getting data from barrow
# getting data from rapid valley
# belushya guba not found
# getting data from princeton
# getting data from atuona
# getting data from kenai
# getting data from castro
# getting data from saskylakh
# getting data from padang
# getting data from sao filipe
# getting data from belaya gora
# getting data from fairbanks
# getting data from clyde river
# getting data from cidreira
# samusu not found
# getting data from eenhana
# sorvag not found
# getting data from fortuna
# getting data from iqaluit
# getting data from governador valadares
# getting data from kashi
# getting data from avarua
# getting data from faanui
# getting data from vaini
# getting data from pimentel
# mys shmidta not found
# getting data from campobello di mazara
# getting data from saint george
# getting data from upernavik
# illoqqortoormiut not found
# getting data from mahebourg
# getting data from bilma
# getting data from muros
# getting data from bredasdorp
# getting data from carnarvon
# getting data from sungairaya
# getting data from semey
# getting data from nanortalik
# getting data from provideniya
# getting data from moyamba
# getting data from madison
# getting data from champerico
# getting data from cayenne
# getting data from nikolskoye
# getting data from labuhan
# getting data from kodiak
# getting data from puerto ayora
# getting data from khandagayty
# getting data from namibe
# getting data from evensk
# tsihombe not found
# getting data from sitka
# getting data from shelburne
# getting data from kaitangata
# getting data from broken hill
# getting data from katsuura
# getting data from steamboat springs
# getting data from mecca
# getting data from biri
# getting data from launceston
# getting data from komsomolskiy
# getting data from kurkino
# chagda not found
# getting data from urucara
# getting data from turkistan
# getting data from vestmannaeyjar
# getting data from olavarria
# getting data from berlevag
# getting data from port alfred
# getting data from oistins
# getting data from moustheni
# getting data from kavaratti
# getting data from pisco
# getting data from bambous virieux
# getting data from san patricio
# getting data from pisz
# tabukiniberu not found
# getting data from georgetown
# getting data from aykhal
# getting data from del rio
# sofiysk not found
# getting data from orlik
# getting data from sao joao da barra
# getting data from yagodnoye
# getting data from seydisehir
# vaitupu not found
# getting data from pagegiai
# getting data from lebu
# getting data from oudtshoorn
# getting data from koumac
# getting data from balloszog
# getting data from trincomalee
# getting data from ilulissat
# getting data from hilo
# getting data from kalianget
# getting data from acheng
# getting data from bosaso
# getting data from olafsvik
# getting data from kemijarvi
# getting data from kattivakkam
# getting data from camana
# getting data from alofi
# getting data from harper
# getting data from arraial do cabo
# getting data from finspang
# getting data from glenluce
# getting data from makakilo city
# getting data from half moon bay
# getting data from auki
# getting data from constitucion
# getting data from jega
# solsvik not found
# getting data from quatre cocos
# getting data from peniche
# attawapiskat not found
# getting data from kieta
# getting data from volnoye
# getting data from breves
# shkotovo-26 not found
# getting data from mitsamiouli
# getting data from clearwater
# getting data from hualmay
# getting data from coquimbo
# getting data from hay river
# getting data from yellowknife
# getting data from shingu
# getting data from cap malheureux
# getting data from jawa
# getting data from shostka
# getting data from hasaki
# getting data from luba
# getting data from shihezi
# getting data from ketchikan
# getting data from isetskoye
# grand river south east not found
# getting data from sosnovo-ozerskoye
# getting data from bagdarin
# getting data from ormara
# getting data from zhigansk
# getting data from laguna
# getting data from saldanha
# getting data from umea
# getting data from guerrero negro
# getting data from havelock
# getting data from victoria
# getting data from ahipara
# getting data from kirkuk
# getting data from santa cruz
# getting data from roald
# getting data from mizque
# getting data from mahibadhoo
# getting data from polonnaruwa
# getting data from flinders
# getting data from hambantota
# getting data from mount gambier
# getting data from talnakh
# getting data from itarema
# getting data from aksarka
# getting data from canaveral
# amderma not found
# getting data from ritchie
# getting data from urumqi
# getting data from novyy svit
# talah not found
# getting data from lorengau
# getting data from lakselv
# getting data from thompson
# getting data from chengde
# getting data from termiz
# getting data from luderitz
# getting data from kutum
# getting data from novaya lyalya
# bolungarvik not found
# getting data from vardo
# getting data from el tigre
# getting data from lagoa
# getting data from eureka
# getting data from lamesa
# getting data from neiafu
# getting data from raga
# getting data from sosva
# getting data from buala
# getting data from geraldton
# getting data from nyurba
# yanchukan not found
# getting data from tilichiki
# getting data from bethel
# getting data from kamina
# getting data from warsaw
# getting data from santiago
# getting data from borogontsy
# getting data from kos
# getting data from dzaoudzi
# getting data from sept-iles
# getting data from tiznit
# getting data from port hedland
# getting data from banjar
# getting data from trelleborg
# getting data from shimoda
# getting data from nabire
# getting data from balkanabat
# getting data from pedasi
# getting data from necochea
# getting data from senneterre
# getting data from mugumu
# getting data from kiama
# getting data from mandurah
# getting data from bathsheba
# getting data from bubaque
# getting data from kruisfontein
# getting data from huilong
# getting data from grand-santi
# getting data from salamiyah
# getting data from matara
# getting data from hofn
# getting data from zalantun
# getting data from miraflores
# getting data from valleyview
# getting data from santa maria
# getting data from puerto suarez
# getting data from newport
# getting data from tautira
# getting data from lagos
# getting data from chimoio
# getting data from kahului
# getting data from lavrentiya
# getting data from bakau
# getting data from taoudenni
# getting data from gimbi
# getting data from tazovskiy
# getting data from bhagwantnagar
# getting data from ayorou
# saleaula not found
# getting data from darhan
# getting data from dubbo
# getting data from saint-pierre
# getting data from ljungby
# ngukurr not found
# getting data from salinopolis
# getting data from panguna
# getting data from thomaston
# getting data from krasnogorsk
# getting data from zaria
# sentyabrskiy not found
# getting data from tete
# getting data from beringovskiy
# getting data from manggar
# getting data from nador
# getting data from rawson
# getting data from verkhoyansk
# getting data from corsicana
# getting data from tuktoyaktuk
# umm jarr not found
# getting data from khatanga
# getting data from mitu
# getting data from praia da vitoria
# getting data from sindor
# getting data from avera
# getting data from denpasar
# getting data from vostok
# getting data from antibes
# getting data from jalu
# getting data from port blair
# getting data from saint-augustin
# getting data from dhidhdhoo
# getting data from malmedy
# getting data from ende
# getting data from husavik
# getting data from bom jesus
# getting data from sakaiminato
# getting data from juegang
# getting data from morant bay
# naftah not found
# getting data from vila velha
# getting data from the valley
# getting data from galesong
# getting data from sfantu gheorghe
# getting data from dondo
# getting data from alyangula
# getting data from mora
# getting data from la ronge
# getting data from viedma
# getting data from san cristobal
# getting data from negombo
# getting data from torbay
# getting data from minchinabad
# getting data from ejido
# getting data from korla
# getting data from panama city
# getting data from elko
# getting data from airai
# getting data from hohhot
# getting data from goedereede
# tasbuget not found
# nizhneyansk not found
# getting data from krasnoselkup
# getting data from niihama
# getting data from adeje
# getting data from freeport
# getting data from mareeba
# getting data from marsh harbour
# getting data from dunedin
# getting data from biak
# getting data from longyearbyen
# getting data from high level
# getting data from yar-sale
# getting data from bara
# getting data from losone
# marcona not found
# getting data from grindavik
# getting data from kloulklubed
# getting data from wattegama
# getting data from yulara
# getting data from maniitsoq
# getting data from weatherford
# getting data from ancud
# getting data from carlsbad
# getting data from sampit
# getting data from iberia
# getting data from poltavka
# getting data from chokwe
# getting data from talcahuano
# getting data from petropavlovsk-kamchatskiy
# getting data from chapais
# getting data from rio gallegos
# getting data from krasnyy yar
# getting data from witbank
# getting data from portland
# getting data from asfi
# getting data from kawambwa
# higuey not found
# getting data from belmonte
# getting data from bahia blanca
# getting data from camopi
# getting data from tres arroyos
# cheuskiny not found
# getting data from knappskog
# getting data from te anau
# getting data from lauria
# getting data from kayerkan
# getting data from caravelas
# rawannawi not found
# getting data from virovitica
# getting data from kozluk
# getting data from dire dawa
# getting data from bayan
# getting data from kupang
# getting data from saint-joseph
# getting data from ibra
# getting data from skibbereen
# getting data from warrnambool
# getting data from los llanos de aridane
# getting data from cap-aux-meules
# getting data from schwarzenbek
# getting data from bodden town
# getting data from novyy urgal
# getting data from agutaya
# getting data from north bend
# getting data from srednekolymsk
# getting data from pokhara
# getting data from helena
# getting data from bentiu
# getting data from merauke
# getting data from acarau
# getting data from chumikan
# getting data from lukulu
# getting data from lisakovsk
# getting data from angoche
# getting data from boda
# getting data from assiniboia
# getting data from moissala
# getting data from yaring
# getting data from ngunguru
# getting data from seredka
# getting data from pittsfield
# getting data from aller
# getting data from kirundo
# getting data from ariquemes
# getting data from priladozhskiy
# getting data from college
# getting data from vysokogornyy
# ondorhaan not found
# getting data from nan
# getting data from dong xoai
# getting data from hailey
# getting data from phek
# getting data from ullal
# getting data from qujing
# getting data from zhanakorgan
# getting data from sur
# getting data from vilyuysk
# getting data from kurilsk
# getting data from yanam
# getting data from muttupet
# getting data from pilot butte
# getting data from iracoubo
# zarakes not found
# lolua not found
# getting data from maymyo
# getting data from suntar
# getting data from porto novo
# getting data from poum
# getting data from durban
# getting data from san clemente
# getting data from alekseyevskoye
# getting data from thaton
# getting data from lazaro cardenas
# getting data from raudeberg
# getting data from luanda
# getting data from panambi
# getting data from trairi
# getting data from kamaishi
# getting data from atbasar
# getting data from leningradskiy
# getting data from adrar
# getting data from calhoun
# getting data from gorin
# getting data from manzanillo
# getting data from obo
# getting data from tuatapere
# getting data from tual
# getting data from potosi
# getting data from moose factory
# getting data from yarada
# getting data from atambua
# getting data from okha
# getting data from oskemen
# getting data from ouallam
# getting data from sao gabriel
# getting data from emba
# getting data from tire
# getting data from sorland
# getting data from guanica
# getting data from san policarpo
# getting data from abu dhabi
# getting data from bukama
# getting data from gushi
# getting data from leh
# getting data from port-gentil
# getting data from altagracia de orituco
# getting data from kysyl-syr
# getting data from havre
# getting data from bulawayo
# getting data from turinskaya sloboda
# getting data from birecik
# getting data from klaksvik
# getting data from limbazi
# getting data from shima
# getting data from umm lajj
# getting data from qaqortoq
# getting data from anloga
# getting data from kananga
# getting data from isangel
# getting data from manuk mangkaw
# getting data from port hardy
# getting data from saint anthony
# getting data from barcelos
# getting data from klooga
# getting data from ban phaeo
# getting data from brae
# getting data from egvekinot
# getting data from huainan
# getting data from khandyga
# getting data from nioro
# getting data from floro
# meyungs not found
# karauzyak not found
# getting data from jiaojiang
# getting data from hailar
# getting data from huambo
# getting data from vao
# getting data from pitlochry
# getting data from charters towers
# getting data from lilongwe
# getting data from peterhead
# getting data from zhuhai
# getting data from panjakent
# getting data from kano
# getting data from buchanan
# getting data from lodja
# getting data from derzhavinsk
# getting data from coffs harbour
# getting data from najran
# getting data from revda
# tumannyy not found
# tidore not found
# getting data from rocha
# getting data from benguela
# getting data from abnub
# palabuhanratu not found
# getting data from gornopravdinsk
# getting data from andenes
# getting data from olga
# getting data from kanigoro
# getting data from tambo
# getting data from palmer
# getting data from khasan
# getting data from bosanska gradiska
# getting data from lodwar
# getting data from alto araguaia
# getting data from shetpe
# getting data from bowen
# getting data from jumla
# getting data from karakol
# getting data from catamarca
# getting data from soyo
# getting data from svay rieng
# getting data from grand-lahou
# getting data from grand gaube
# getting data from hobyo
# achisay not found
# getting data from semnan
# getting data from saint-francois
# getting data from selaphum
# getting data from collie
# getting data from augusta
# kuche not found
# getting data from tessalit
# getting data from penco
# getting data from felipe carrillo puerto
# getting data from bilibino
# getting data from kiunga
# getting data from adre
# getting data from amurzet
# bajo baudo not found

# %%
print(lat)
print(long)
print(temp)
print(humidity)
print(windspeed)
print(city_name)
print(country)
print(date_date)
print(clouds)
# Out:
# [-2.5744]
# [150.7967]
# [301.5]
# [67]
# [2.95]
# ['Kavieng']
# ['PG']
# [1615412218]
# [98]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
summary_city_info = {"City": city_name, 
                     "Lat": lat, 
                     "Lng": long,
                     "Max Temp": temp,
                     "Humidity": humidity, 
                     "Cloudiness": clouds, 
                     "Wind Speed": windspeed, 
                     "Country": country, 
                     "date": date_date}
summary_city_info_df = pd.DataFrame(summary_city_info)
summary_city_info_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Kavieng  -2.5744  150.7967    301.50        67          98
# 1       Rikitea -23.1203 -134.9692    299.22        75          11
# 2  Vangaindrano -23.3500   47.6000    297.30        87          40
# 3     Jamestown  42.0970  -79.2353    287.94        27           1
# 4       Salalah  17.0151   54.0924    297.15        41           0
#
#    Wind Speed Country        date
# 0        2.95      PG  1615412938
# 1        7.79      PF  1615412939
# 2        2.31      MG  1615412940
# 3        5.61      US  1615412235
# 4        2.06      OM  1615412390

# %%
southhem = summary_city_info_df['Lat'] < 0
northhem = summary_city_info_df['Lat'] > 0

# %%
summary_city_info_df[northhem]
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 3                 Jamestown  42.0970  -79.2353    287.94        27
# 4                   Salalah  17.0151   54.0924    297.15        41
# 6                   Aklavik  68.2191 -135.0107    260.15        78
# 8                     Tiksi  71.6872  128.8694    242.48        83
# 10                   Albany  42.6001  -73.9662    284.65        33
# ..                      ...      ...       ...       ...       ...
# 561                Tessalit  20.1986    1.0114    294.64        20
# 563  Felipe Carrillo Puerto  19.5833  -88.0500    300.53        54
# 564                Bilibino  68.0546  166.4372    244.50        79
# 566                    Adré  13.4667   22.2000    297.35        16
# 567                 Amurzet  47.6967  131.0981    266.38        94
#
#      Cloudiness  Wind Speed Country        date
# 3             1        5.61      US  1615412235
# 4             0        2.06      OM  1615412390
# 6            90        2.06      CA  1615412175
# 8            78       10.67      RU  1615412395
# 10           40        6.17      US  1615412133
# ..          ...         ...     ...         ...
# 561         100        5.17      ML  1615413385
# 563          76        3.59      MX  1615413387
# 564           0        1.26      RU  1615413388
# 566           0        5.70      TD  1615413389
# 567           1        2.79      RU  1615413390
#
# [386 rows x 9 columns]

# %%
summary_city_info_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  568.000000  568.000000  568.000000  568.000000  568.000000  568.000000
# mean    19.909268   21.681328  284.515775   72.966549   51.903169    3.707095
# std     33.535072   88.624244   16.227768   20.519890   38.868513    2.905879
# min    -54.800000 -179.166700  236.050000    4.000000    0.000000    0.190000
# 25%     -8.259175  -54.345800  274.357500   64.000000   10.000000    1.547500
# 50%     22.426100   24.693050  290.740000   79.000000   54.000000    3.085000
# 75%     49.271675  100.164475  297.655000   88.000000   90.000000    5.140000
# max     78.218600  179.316700  306.740000  100.000000  100.000000   16.460000
#
#                date
# count  5.680000e+02
# mean   1.615413e+09
# std    2.008137e+02
# min    1.615412e+09
# 25%    1.615413e+09
# 50%    1.615413e+09
# 75%    1.615413e+09
# max    1.615413e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# there are none that was found through the .describe() above

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#plt.scatter x,y,marker,facecolor,edgecolor,s=,alpha
lataxis = summary_city_info_df['Lat']
tempaxis = summary_city_info_df['Max Temp']
humaxis = summary_city_info_df['Humidity']
cldaxis = summary_city_info_df['Cloudiness']
wndaxis = summary_city_info_df['Wind Speed']

plt.scatter(lataxis,tempaxis,marker='o',facecolor='orange',edgecolor='black',alpha=0.75)
plt.title("Latitude vs. Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.grid()
plt.show()
#This is analyzing that there is a good coorelation between latitude and temperature

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(lataxis,humaxis,marker='+',facecolor='blue',edgecolor='black',alpha=0.75)
plt.title("Latitude vs. Humidity Plot")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
plt.show()
#this is showing that the latitude does not give a clear answer about the humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(lataxis,cldaxis,marker='^',facecolor='green',edgecolor='black',alpha=0.75)
plt.title("Latitude vs. Cloudiness Plot")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
plt.show()
#this is showing that the latitudes greater than 0 have a higher cloud cover

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(lataxis,wndaxis,marker='o',facecolor='red',edgecolor='black',alpha=0.75)
plt.title("Latitude vs. Wind Speed Plot")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
plt.show()
#this is showing that windspeed, ragardless of latitude, typically stays lower,
#though peeks higher more frequently as we get above the equator

# %% [markdown]
# ## Linear Regression

# %%
#x_values = housing_data['RM']
#y_values = housing_data['MEDV']
#(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#regress_values = x_values * slope + intercept
#line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#plt.scatter(x_values,y_values)
#plt.plot(x_values,regress_values,"r-")
#plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.xlabel('Rooms in House')
#plt.ylabel('Median House Prices ($1000)')
#*print(f"The r-squared is: {rvalue**2}")
#plt.show()

#    variables for the hemispheres
#northhem
#southhem

#lataxis = summary_city_info_df['Lat']
#tempaxis = summary_city_info_df['Max Temp']
#humaxis = summary_city_info_df['Humidity']
#cldaxis = summary_city_info_df['Cloudiness']
#wndaxis = summary_city_info_df['Wind Speed']

# max temp
nortemp = summary_city_info_df[northhem]['Max Temp']
soutemp = summary_city_info_df[southhem]['Max Temp']
# latitude
norlat = summary_city_info_df[northhem]['Lat']
soulat = summary_city_info_df[southhem]['Lat']
# humidity %
norhum = summary_city_info_df[northhem]['Humidity']
souhum = summary_city_info_df[southhem]['Humidity']
# cloudiness %
norcloud = summary_city_info_df[northhem]['Cloudiness']
soucloud = summary_city_info_df[southhem]['Cloudiness']
# wind speed mph
norwind = summary_city_info_df[northhem]['Wind Speed']
souwind = summary_city_info_df[southhem]['Wind Speed']
# Out:
# 386

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#df.to_csv()
