# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 652

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#creating empty lists and sets
#for loop to append the correct information to find the city info

lat = []
long = []
temp = []
humidity = []
windspeed = []
city_name = []
clouds = []
country = []
date_date = []
citynum = 0
citynull = 0

for city in cities:
    url_url = f"http://api.openweathermap.org/data/2.5/weather?&q={city}&appid={weather_api_key}"
    response = requests.get(url_url)
    responsej = response.json()
    time.sleep(.5)
    try:
        lat.append(responsej['coord']['lat'])
        long.append(responsej['coord']['lon'])
        temp.append(responsej['main']['temp'])
        humidity.append(responsej['main']['humidity'])
        windspeed.append(responsej['wind']['speed'])
        city_name.append(responsej['name'])
        country.append(responsej['sys']['country'])
        date_date.append(responsej['dt'])
        clouds.append(responsej['clouds']['all'])
        citynum += 1
        print(f"getting data from {citynum} - {city}")
    except:
        citynull +=1
        print(f"{citynull} - {city} not found")
        pass
# Out:
# getting data from 1 - poum
# getting data from 2 - georgetown
# getting data from 3 - port elizabeth
# getting data from 4 - ketchikan
# getting data from 5 - sungairaya
# getting data from 6 - cockburn town
# getting data from 7 - cape town
# 1 - babanusah not found
# getting data from 8 - mataura
# getting data from 9 - barrow
# getting data from 10 - aswan
# getting data from 11 - luderitz
# getting data from 12 - opuwo
# getting data from 13 - andreyevo
# getting data from 14 - puerto ayora
# getting data from 15 - banikoara
# getting data from 16 - mogzon
# getting data from 17 - marawi
# getting data from 18 - jega
# getting data from 19 - bethel
# getting data from 20 - rikitea
# getting data from 21 - gazli
# getting data from 22 - pevek
# getting data from 23 - avarua
# getting data from 24 - nelson bay
# getting data from 25 - berdigestyakh
# getting data from 26 - vaini
# getting data from 27 - zhezkazgan
# getting data from 28 - bengkulu
# getting data from 29 - bluff
# 2 - malwan not found
# getting data from 30 - gorontalo
# 3 - grand river south east not found
# getting data from 31 - qaanaaq
# getting data from 32 - kodiak
# getting data from 33 - te anau
# getting data from 34 - columbus
# getting data from 35 - punta arenas
# getting data from 36 - yulara
# getting data from 37 - port alfred
# getting data from 38 - broken hill
# getting data from 39 - chifeng
# getting data from 40 - tautira
# getting data from 41 - arraial do cabo
# getting data from 42 - mar del plata
# getting data from 43 - fortuna
# getting data from 44 - salta
# getting data from 45 - bredasdorp
# getting data from 46 - albany
# getting data from 47 - basco
# getting data from 48 - hobart
# getting data from 49 - miri
# getting data from 50 - provideniya
# getting data from 51 - saint-philippe
# getting data from 52 - ambilobe
# getting data from 53 - tuktoyaktuk
# getting data from 54 - guerrero negro
# getting data from 55 - ampanihy
# getting data from 56 - ahipara
# getting data from 57 - badovinci
# getting data from 58 - candolim
# getting data from 59 - thompson
# 4 - taolanaro not found
# 5 - sorvag not found
# getting data from 60 - mayo
# getting data from 61 - atambua
# getting data from 62 - batemans bay
# getting data from 63 - werda
# getting data from 64 - torbay
# getting data from 65 - jamestown
# getting data from 66 - shubarshi
# 6 - amderma not found
# getting data from 67 - karagach
# getting data from 68 - iqaluit
# getting data from 69 - kaitangata
# getting data from 70 - inuvik
# getting data from 71 - hithadhoo
# getting data from 72 - baykit
# getting data from 73 - laguna
# getting data from 74 - buri
# getting data from 75 - anchorage
# getting data from 76 - cidreira
# getting data from 77 - busselton
# getting data from 78 - pangnirtung
# getting data from 79 - saldanha
# getting data from 80 - okha
# getting data from 81 - avera
# getting data from 82 - bubaque
# getting data from 83 - bandarbeyla
# getting data from 84 - tiksi
# getting data from 85 - aklavik
# 7 - attawapiskat not found
# getting data from 86 - tiznit
# getting data from 87 - wajima
# getting data from 88 - esperance
# 8 - karakendzha not found
# getting data from 89 - east london
# getting data from 90 - ushuaia
# getting data from 91 - ancud
# getting data from 92 - sao francisco de assis
# getting data from 93 - bintulu
# getting data from 94 - tuatapere
# getting data from 95 - lompoc
# getting data from 96 - xiaoshan
# getting data from 97 - korla
# getting data from 98 - arcata
# getting data from 99 - bukit baru
# getting data from 100 - itarema
# getting data from 101 - carnarvon
# 9 - belushya guba not found
# getting data from 102 - dumas
# getting data from 103 - touros
# getting data from 104 - nanortalik
# getting data from 105 - axim
# getting data from 106 - maltahohe
# getting data from 107 - tarko-sale
# 10 - illoqqortoormiut not found
# getting data from 108 - berlevag
# getting data from 109 - tornio
# getting data from 110 - turgutlu
# getting data from 111 - havre-saint-pierre
# getting data from 112 - chuy
# getting data from 113 - tasiilaq
# getting data from 114 - hermanus
# getting data from 115 - catalina
# getting data from 116 - geraldton
# getting data from 117 - pierre
# getting data from 118 - comodoro rivadavia
# getting data from 119 - khilok
# getting data from 120 - minab
# getting data from 121 - khash
# getting data from 122 - bambous virieux
# getting data from 123 - honningsvag
# getting data from 124 - kirakira
# getting data from 125 - saint-pierre
# getting data from 126 - scarborough
# getting data from 127 - bathsheba
# getting data from 128 - mafinga
# getting data from 129 - santa fe
# getting data from 130 - kruisfontein
# getting data from 131 - sur
# getting data from 132 - kouango
# getting data from 133 - necochea
# getting data from 134 - shimoda
# getting data from 135 - butaritari
# getting data from 136 - flin flon
# 11 - ljaskovec not found
# getting data from 137 - sao filipe
# getting data from 138 - orcopampa
# getting data from 139 - college
# getting data from 140 - dunedin
# getting data from 141 - chachapoyas
# 12 - marcona not found
# getting data from 142 - pisco
# getting data from 143 - seoul
# getting data from 144 - brae
# getting data from 145 - hamilton
# getting data from 146 - hilo
# getting data from 147 - port lincoln
# getting data from 148 - cajamarca
# getting data from 149 - chapais
# getting data from 150 - mpongwe
# getting data from 151 - san juan
# getting data from 152 - puri
# getting data from 153 - kenitra
# getting data from 154 - castro
# getting data from 155 - mandurah
# getting data from 156 - vanavara
# getting data from 157 - merauke
# getting data from 158 - kachug
# 13 - mocambique not found
# getting data from 159 - phalodi
# getting data from 160 - igarka
# getting data from 161 - nikolskoye
# getting data from 162 - houma
# getting data from 163 - beira
# getting data from 164 - waipawa
# 14 - vaitupu not found
# getting data from 165 - tucurui
# getting data from 166 - hofn
# 15 - ambodifototra not found
# getting data from 167 - aksarka
# getting data from 168 - golyshmanovo
# getting data from 169 - ejido
# getting data from 170 - kayes
# getting data from 171 - new norfolk
# getting data from 172 - longyan
# getting data from 173 - yellowknife
# getting data from 174 - maniitsoq
# getting data from 175 - roald
# getting data from 176 - tabou
# getting data from 177 - okhotsk
# 16 - barentsburg not found
# getting data from 178 - constitucion
# getting data from 179 - koygorodok
# getting data from 180 - front royal
# getting data from 181 - beloha
# getting data from 182 - union city
# getting data from 183 - waingapu
# getting data from 184 - quartucciu
# getting data from 185 - mackay
# getting data from 186 - semey
# getting data from 187 - victoria
# getting data from 188 - toora-khem
# getting data from 189 - forbes
# getting data from 190 - richards bay
# getting data from 191 - cap-aux-meules
# getting data from 192 - belle fourche
# getting data from 193 - taksimo
# getting data from 194 - saint-francois
# getting data from 195 - mount gambier
# getting data from 196 - kousseri
# getting data from 197 - rio branco do sul
# 17 - mys shmidta not found
# getting data from 198 - poltavka
# 18 - sao miguel do oeste not found
# getting data from 199 - port augusta
# getting data from 200 - upernavik
# getting data from 201 - chokurdakh
# getting data from 202 - ranong
# getting data from 203 - severo-yeniseyskiy
# getting data from 204 - tura
# getting data from 205 - cap malheureux
# getting data from 206 - paramonga
# getting data from 207 - tezu
# getting data from 208 - kuchinarai
# getting data from 209 - khandbari
# getting data from 210 - araouane
# 19 - palabuhanratu not found
# getting data from 211 - ribeira grande
# getting data from 212 - isangel
# getting data from 213 - oranjestad
# getting data from 214 - saint pete beach
# getting data from 215 - atuona
# getting data from 216 - karatau
# getting data from 217 - visby
# getting data from 218 - mahebourg
# getting data from 219 - dawei
# getting data from 220 - boffa
# getting data from 221 - rugby
# getting data from 222 - cam ranh
# getting data from 223 - dali
# getting data from 224 - mitu
# getting data from 225 - peniche
# getting data from 226 - bolshevik
# getting data from 227 - broome
# getting data from 228 - qasigiannguit
# getting data from 229 - kapaa
# getting data from 230 - dikson
# getting data from 231 - puerto el triunfo
# getting data from 232 - luganville
# getting data from 233 - nurota
# 20 - khonuu not found
# getting data from 234 - alice springs
# getting data from 235 - maraa
# getting data from 236 - helena
# getting data from 237 - tucupita
# getting data from 238 - saint george
# getting data from 239 - naftalan
# getting data from 240 - eyl
# getting data from 241 - sao felix do xingu
# getting data from 242 - the valley
# getting data from 243 - joao pinheiro
# getting data from 244 - talnakh
# 21 - tabiauea not found
# getting data from 245 - airai
# getting data from 246 - padang
# getting data from 247 - ayan
# getting data from 248 - sao joao da barra
# getting data from 249 - bam
# getting data from 250 - galle
# getting data from 251 - newberry
# getting data from 252 - vila velha
# getting data from 253 - foam lake
# getting data from 254 - saskylakh
# getting data from 255 - marzuq
# 22 - wulanhaote not found
# getting data from 256 - lavrentiya
# getting data from 257 - marsa matruh
# getting data from 258 - labuan
# getting data from 259 - sundby
# getting data from 260 - khatanga
# getting data from 261 - severo-kurilsk
# getting data from 262 - kuopio
# getting data from 263 - shuyskoye
# getting data from 264 - ogaminana
# getting data from 265 - bilibino
# getting data from 266 - narsaq
# getting data from 267 - rantauprapat
# getting data from 268 - masty
# getting data from 269 - codrington
# getting data from 270 - floro
# getting data from 271 - bira
# getting data from 272 - agudos
# getting data from 273 - goma
# getting data from 274 - anadyr
# getting data from 275 - rio de janeiro
# getting data from 276 - bilma
# getting data from 277 - cabo san lucas
# getting data from 278 - lethem
# getting data from 279 - chenzhou
# getting data from 280 - lufilufi
# getting data from 281 - manono
# getting data from 282 - caramay
# getting data from 283 - lebu
# getting data from 284 - aviles
# getting data from 285 - pervomayskoye
# getting data from 286 - hasaki
# getting data from 287 - oksfjord
# getting data from 288 - kahului
# getting data from 289 - soyo
# getting data from 290 - tarnos
# getting data from 291 - san jose
# getting data from 292 - dolinsk
# getting data from 293 - turayf
# getting data from 294 - tiarei
# getting data from 295 - trelew
# getting data from 296 - tacoronte
# getting data from 297 - caravelas
# getting data from 298 - makat
# getting data from 299 - xiamen
# getting data from 300 - ravar
# getting data from 301 - port blair
# getting data from 302 - wailuku
# getting data from 303 - souillac
# getting data from 304 - grand gaube
# getting data from 305 - kant
# getting data from 306 - baicheng
# getting data from 307 - ajdabiya
# getting data from 308 - newport
# 23 - tunduru not found
# 24 - lolua not found
# 25 - skalistyy not found
# getting data from 309 - tomatlan
# getting data from 310 - san cristobal
# getting data from 311 - santiago del estero
# getting data from 312 - oytal
# getting data from 313 - vanimo
# getting data from 314 - mirnyy
# getting data from 315 - ponnani
# getting data from 316 - teguldet
# getting data from 317 - vaitape
# getting data from 318 - norrtalje
# 26 - saleaula not found
# getting data from 319 - yatou
# getting data from 320 - corrente
# getting data from 321 - shingu
# getting data from 322 - santiago
# getting data from 323 - alofi
# getting data from 324 - bonthe
# getting data from 325 - ponta do sol
# getting data from 326 - mizan teferi
# 27 - talah not found
# 28 - tawkar not found
# 29 - karamea not found
# getting data from 327 - batagay-alyta
# getting data from 328 - funadhoo
# getting data from 329 - emerald
# getting data from 330 - marienburg
# getting data from 331 - slave lake
# getting data from 332 - pandan
# getting data from 333 - susanville
# getting data from 334 - olafsvik
# 30 - eskasem not found
# getting data from 335 - ulladulla
# getting data from 336 - leningradskiy
# getting data from 337 - outjo
# getting data from 338 - norman wells
# getting data from 339 - rawah
# getting data from 340 - moyale
# getting data from 341 - ust-kalmanka
# getting data from 342 - nioro
# getting data from 343 - linqu
# 31 - umm ruwabah not found
# getting data from 344 - salalah
# getting data from 345 - lagoa
# getting data from 346 - fort-shevchenko
# getting data from 347 - paita
# getting data from 348 - ust-tsilma
# 32 - umzimvubu not found
# getting data from 349 - baker city
# getting data from 350 - sijunjung
# 33 - louisbourg not found
# getting data from 351 - calvia
# getting data from 352 - ugep
# getting data from 353 - faanui
# getting data from 354 - mitsamiouli
# getting data from 355 - vardo
# getting data from 356 - point pedro
# getting data from 357 - kamenka
# getting data from 358 - ipameri
# 34 - bajo baudo not found
# getting data from 359 - shitanjing
# getting data from 360 - hobyo
# getting data from 361 - dalvik
# getting data from 362 - udaipura
# getting data from 363 - gonbad-e qabus
# getting data from 364 - barra do garcas
# getting data from 365 - talara
# getting data from 366 - lazarev
# getting data from 367 - lotoshino
# getting data from 368 - woensdrecht
# getting data from 369 - dargaville
# getting data from 370 - sulangan
# getting data from 371 - grand-santi
# getting data from 372 - tommot
# getting data from 373 - ust-maya
# getting data from 374 - komsomolskiy
# getting data from 375 - benghazi
# getting data from 376 - moron
# getting data from 377 - bac lieu
# getting data from 378 - kailua
# getting data from 379 - dukat
# getting data from 380 - rosarno
# getting data from 381 - khalkhal
# getting data from 382 - kharp
# getting data from 383 - mariental
# getting data from 384 - kununurra
# getting data from 385 - sitka
# getting data from 386 - grindavik
# getting data from 387 - lingao
# getting data from 388 - meulaboh
# getting data from 389 - kaeo
# getting data from 390 - margate
# getting data from 391 - poso
# getting data from 392 - deniliquin
# getting data from 393 - paamiut
# 35 - jomalig not found
# getting data from 394 - limpapa
# getting data from 395 - windhoek
# getting data from 396 - kavieng
# getting data from 397 - auki
# getting data from 398 - opunake
# getting data from 399 - edea
# getting data from 400 - karpogory
# getting data from 401 - srednekolymsk
# getting data from 402 - longyearbyen
# getting data from 403 - hay river
# 36 - nizhneyansk not found
# getting data from 404 - juneau
# getting data from 405 - sal rei
# getting data from 406 - lakes entrance
# getting data from 407 - half moon bay
# getting data from 408 - vostok
# getting data from 409 - doka
# getting data from 410 - farafangana
# getting data from 411 - la plata
# getting data from 412 - puerto escondido
# getting data from 413 - cururupu
# getting data from 414 - passagem franca
# getting data from 415 - dourbali
# 37 - tungkang not found
# 38 - phan rang not found
# getting data from 416 - alamogordo
# getting data from 417 - bairiki
# getting data from 418 - saint-leu
# getting data from 419 - deer lake
# getting data from 420 - starotimoshkino
# getting data from 421 - sechura
# getting data from 422 - qandala
# getting data from 423 - cayenne
# getting data from 424 - lazaro cardenas
# getting data from 425 - lorengau
# getting data from 426 - sistranda
# getting data from 427 - aripuana
# getting data from 428 - kundiawa
# 39 - ruatoria not found
# getting data from 429 - manokwari
# getting data from 430 - warrnambool
# getting data from 431 - port hawkesbury
# getting data from 432 - la ronge
# getting data from 433 - berdsk
# getting data from 434 - todos santos
# getting data from 435 - karakol
# getting data from 436 - sarakhs
# getting data from 437 - sao francisco do sul
# getting data from 438 - kasane
# getting data from 439 - elko
# getting data from 440 - kollegal
# getting data from 441 - atar
# getting data from 442 - wangkui
# getting data from 443 - saint anthony
# getting data from 444 - podor
# getting data from 445 - rawson
# getting data from 446 - tilichiki
# getting data from 447 - ukmerge
# getting data from 448 - karratha
# getting data from 449 - bara
# 40 - os not found
# getting data from 450 - namibe
# getting data from 451 - balkhash
# getting data from 452 - upata
# getting data from 453 - dakoro
# getting data from 454 - mabaruma
# getting data from 455 - bakchar
# getting data from 456 - yurino
# getting data from 457 - lima
# getting data from 458 - kumbo
# 41 - turtkul not found
# 42 - saleilua not found
# getting data from 459 - ledyard
# getting data from 460 - vuktyl
# getting data from 461 - camacha
# getting data from 462 - cozumel
# getting data from 463 - malakal
# getting data from 464 - pangody
# getting data from 465 - charters towers
# getting data from 466 - makakilo city
# getting data from 467 - vestmannaeyjar
# getting data from 468 - san ignacio
# getting data from 469 - shache
# getting data from 470 - dudinka
# getting data from 471 - lakatoro
# 43 - sahrak not found
# getting data from 472 - fukue
# 44 - kamenskoye not found
# getting data from 473 - nakamura
# getting data from 474 - zhigansk
# getting data from 475 - luis correia
# getting data from 476 - camocim
# getting data from 477 - tecoanapa
# getting data from 478 - maraba
# getting data from 479 - bocana de paiwas
# getting data from 480 - adrar
# getting data from 481 - baraya
# getting data from 482 - rochester
# getting data from 483 - ixtapa
# getting data from 484 - okahandja
# getting data from 485 - saint-augustin
# getting data from 486 - neka
# getting data from 487 - sao jose da coroa grande
# getting data from 488 - bundaberg
# getting data from 489 - san luis
# getting data from 490 - montepuez
# getting data from 491 - kisangani
# getting data from 492 - beroroha
# getting data from 493 - walvis bay
# getting data from 494 - payo
# getting data from 495 - aranos
# getting data from 496 - kurilsk
# getting data from 497 - snina
# getting data from 498 - omboue
# 45 - samusu not found
# getting data from 499 - camana
# getting data from 500 - vila
# getting data from 501 - choctaw
# getting data from 502 - eureka
# getting data from 503 - fairbanks
# getting data from 504 - chernyshevskiy
# 46 - karaul not found
# getting data from 505 - teguise
# getting data from 506 - gusau
# getting data from 507 - maneadero
# getting data from 508 - san carlos
# getting data from 509 - kenai
# getting data from 510 - usinsk
# getting data from 511 - yongchang
# getting data from 512 - skjervoy
# getting data from 513 - port hardy
# getting data from 514 - marsh harbour
# getting data from 515 - erenhot
# getting data from 516 - tandalti
# getting data from 517 - armeria
# getting data from 518 - helong
# getting data from 519 - champerico
# getting data from 520 - sambava
# getting data from 521 - laksham
# getting data from 522 - gondar
# getting data from 523 - cervo
# getting data from 524 - casablanca
# getting data from 525 - yar-sale
# getting data from 526 - myaundzha
# getting data from 527 - gambela
# getting data from 528 - tselinnoye
# 47 - barawe not found
# 48 - tidore not found
# getting data from 529 - salinas
# getting data from 530 - shabo
# 49 - labutta not found
# getting data from 531 - rio gallegos
# getting data from 532 - venice
# getting data from 533 - chulucanas
# 50 - bolungarvik not found
# getting data from 534 - dwarka
# getting data from 535 - lac du bonnet
# getting data from 536 - sosua
# getting data from 537 - moose factory
# 51 - bagasara not found
# getting data from 538 - asosa
# 52 - tumannyy not found
# 53 - tsihombe not found
# 54 - ozgon not found
# getting data from 539 - cherskiy
# getting data from 540 - coachella
# getting data from 541 - boa vista
# getting data from 542 - novoagansk
# getting data from 543 - chicama
# getting data from 544 - cabedelo
# getting data from 545 - grand bend
# 55 - sentyabrskiy not found
# getting data from 546 - ziway
# getting data from 547 - izhmorskiy
# getting data from 548 - manchester
# getting data from 549 - rio grande
# getting data from 550 - los algarrobos
# getting data from 551 - jiexiu
# getting data from 552 - nizhnyaya tavda
# getting data from 553 - tenenkou
# getting data from 554 - edson
# getting data from 555 - ilulissat
# getting data from 556 - san carlos de bariloche
# getting data from 557 - raudeberg
# getting data from 558 - portland
# getting data from 559 - bandrele
# getting data from 560 - redlands
# getting data from 561 - surgut
# getting data from 562 - sotouboua
# getting data from 563 - westport
# getting data from 564 - matara
# getting data from 565 - laguna de perlas
# 56 - rungata not found
# getting data from 566 - mehamn
# 57 - tanjong sepat not found
# getting data from 567 - aasiaat
# getting data from 568 - labuhan
# 58 - halalo not found
# getting data from 569 - narva-joesuu
# getting data from 570 - wetaskiwin
# getting data from 571 - homer
# getting data from 572 - tinskoy
# getting data from 573 - sioux lookout
# getting data from 574 - aguas formosas
# getting data from 575 - manicore
# getting data from 576 - pemberton
# getting data from 577 - barcelos
# getting data from 578 - muisne
# getting data from 579 - verkhnevilyuysk
# 59 - daxian not found
# getting data from 580 - talcahuano
# getting data from 581 - turukhansk
# getting data from 582 - ambon
# getting data from 583 - takoradi
# getting data from 584 - hokitika
# getting data from 585 - port moresby
# getting data from 586 - fomboni
# getting data from 587 - buraydah
# getting data from 588 - elbrus
# getting data from 589 - urengoy
# getting data from 590 - ostrovnoy
# getting data from 591 - lichtenfels
# getting data from 592 - russell
# getting data from 593 - bloomsburg

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#creating sorted info into dataframe
summary_city_info = {"City": city_name, 
                     "Lat": lat, 
                     "Lng": long,
                     "Max Temp": temp,
                     "Humidity": humidity, 
                     "Cloudiness": clouds, 
                     "Wind Speed": windspeed, 
                     "Country": country, 
                     "date": date_date}
summary_city_info_df = pd.DataFrame(summary_city_info)
summary_city_info_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Poum -20.2333  164.0167    299.68        71          26
# 1     George Town   5.4112  100.3354    297.63        94          20
# 2  Port Elizabeth -33.9180   25.5701    293.15        94           0
# 3       Ketchikan  55.3422 -131.6461    276.15        60          90
# 4     Sungai Raya   0.7000  108.9000    297.46        89          61
#
#    Wind Speed Country        date
# 0        4.87      NC  1615590416
# 1        1.54      MY  1615590416
# 2        2.40      ZA  1615590355
# 3        3.09      US  1615590361
# 4        2.27      ID  1615590418

# %%
#seperated df to northern and southern hems

southhem = summary_city_info_df['Lat'] < 0
northhem = summary_city_info_df['Lat'] > 0

# %%
summary_city_info_df[northhem]
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1      George Town   5.4112  100.3354    297.63        94          20
# 3        Ketchikan  55.3422 -131.6461    276.15        60          90
# 4      Sungai Raya   0.7000  108.9000    297.46        89          61
# 5    Cockburn Town  21.4612  -71.1419    297.68        75          15
# 8           Barrow  71.2906 -156.7887    244.15        63           1
# ..             ...      ...       ...       ...       ...         ...
# 588        Urengoy  65.9667   78.3667    256.94        91         100
# 589      Ostrovnoy  68.0531   39.5131    262.50        90          96
# 590    Lichtenfels  50.1457   11.0593    277.08        77         100
# 591        Russell  32.3502  -85.1999    297.53        41           1
# 592     Bloomsburg  41.0037  -76.4549    287.13        19           1
#
#      Wind Speed Country        date
# 1          1.54      MY  1615590416
# 3          3.09      US  1615590361
# 4          2.27      ID  1615590418
# 5          9.31      TC  1615590124
# 8          6.69      US  1615590421
# ..          ...     ...         ...
# 588        9.36      RU  1615590887
# 589        7.42      RU  1615590888
# 590        1.34      DE  1615590888
# 591        3.09      US  1615590889
# 592        2.57      US  1615590797
#
# [406 rows x 9 columns]

# %%
summary_city_info_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  593.000000  593.000000  593.000000  593.000000  593.000000  593.000000
# mean    19.622542   15.241049  285.008954   71.853288   48.632378    3.929174
# std     33.921495   91.428023   15.446806   21.841808   39.192048    2.714998
# min    -54.800000 -175.200000  241.940000    5.000000    0.000000    0.130000
# 25%     -7.300000  -65.102300  276.040000   61.000000    5.000000    1.780000
# 50%     21.346900   19.961900  290.790000   77.000000   41.000000    3.460000
# 75%     50.100100   92.750000  297.400000   89.000000   90.000000    5.430000
# max     78.218600  178.416700  304.440000  100.000000  100.000000   18.520000
#
#                date
# count  5.930000e+02
# mean   1.615591e+09
# std    1.696983e+02
# min    1.615590e+09
# 25%    1.615591e+09
# 50%    1.615591e+09
# 75%    1.615591e+09
# max    1.615591e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
print("There are no cities with humidity over 100% as found through the describe")
# Out:
# There are no cities with humidity over 100% as found through the describe

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# there are none that was found through the .describe() above

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Latitude vs. Temperature Plot
lataxis = summary_city_info_df['Lat']
tempaxis = summary_city_info_df['Max Temp']
humaxis = summary_city_info_df['Humidity']
cldaxis = summary_city_info_df['Cloudiness']
wndaxis = summary_city_info_df['Wind Speed']

plt.scatter(lataxis,tempaxis,marker='o',facecolor='orange',edgecolor='black',alpha=0.75)
plt.title("Latitude vs. Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.grid()
plt.show()
print("This is analyzing that there is a good coorelation between latitude and temperature")
# Out:
# This is analyzing that there is a good coorelation between latitude and temperature

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Latitude vs. Humidity Plot
plt.scatter(lataxis,humaxis,marker='+',facecolor='blue',edgecolor='black',alpha=0.75)
plt.title("Latitude vs. Humidity Plot")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
plt.show()
print("this is showing that the latitude does not give a clear answer about the humidity")
# Out:
# this is showing that the latitude does not give a clear answer about the humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Latitude vs. Cloudiness Plot
plt.scatter(lataxis,cldaxis,marker='^',facecolor='green',edgecolor='black',alpha=0.75)
plt.title("Latitude vs. Cloudiness Plot")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
plt.show()
print("this is showing that the latitudes greater than 0 have a higher cloud cover")
# Out:
# this is showing that the latitudes greater than 0 have a higher cloud cover

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Latitude vs. Wind Speed Plot
plt.scatter(lataxis,wndaxis,marker='o',facecolor='red',edgecolor='black',alpha=0.75)
plt.title("Latitude vs. Wind Speed Plot")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
plt.show()
print("this is showing that windspeed, ragardless of latitude, typically stays lower,though peeks higher more frequently as we get above the equator")
# Out:
# this is showing that windspeed, ragardless of latitude, typically stays lower,though peeks higher more frequently as we get above the equator

# %% [markdown]
# ## Linear Regression

# %%
#    variables for the hemisphere data
#northhem
#southhem

# max temp
nortemp = summary_city_info_df[northhem]['Max Temp']
soutemp = summary_city_info_df[southhem]['Max Temp']
# latitude
norlat = summary_city_info_df[northhem]['Lat']
soulat = summary_city_info_df[southhem]['Lat']
# humidity %
norhum = summary_city_info_df[northhem]['Humidity']
souhum = summary_city_info_df[southhem]['Humidity']
# cloudiness %
norcloud = summary_city_info_df[northhem]['Cloudiness']
soucloud = summary_city_info_df[southhem]['Cloudiness']
# wind speed mph
norwind = summary_city_info_df[northhem]['Wind Speed']
souwind = summary_city_info_df[southhem]['Wind Speed']

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(nortemp, norlat)
regress_values = nortemp * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(nortemp, norlat)
plt.plot(nortemp,regress_values,"r-")
plt.annotate(line_eq,(240,20),fontsize=15,color="red")
plt.xlabel('Northern Hemisphere Max Temp')
plt.ylabel('Northern Hemisphere Latitude')
print(f"The r-squared is: {rvalue**2}")
rsquare_val = round(rvalue**2,2)
print(f"This says the Max Temp and Latitude in the Northern Hemisphere as a coorelation of {rsquare_val}% which is a great coorelation")

plt.show()
# Out:
# The r-squared is: 0.8086610782067171
# This says the Max Temp and Latitude in the Northern Hemisphere as a coorelation of 0.81% which is a great coorelation

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Max Temp vs. Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(soutemp, soulat)
regress_values = soutemp * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(soutemp, soulat)
plt.plot(soutemp,regress_values,"r-")
plt.annotate(line_eq,(290,-52),fontsize=15,color="red")
plt.xlabel('Southern Hemisphere Max Temp')
plt.ylabel('Southern Hemisphere Latitude')
print(f"The r-squared is: {rvalue**2}")
rsquare_val = round(rvalue**2,2)
print(f"This says the Max Temp and Latitude in the Southern Hemisphere as a coorelation of {rsquare_val}% which says there is no coorelation")

plt.show()
# Out:
# The r-squared is: 0.25445252051596257
# This says the Max Temp and Latitude in the Southern Hemisphere as a coorelation of 0.25% which says there is no coorelation

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(norhum, norlat)
regress_values = norhum * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(norhum, norlat)
plt.plot(norhum,regress_values,"r-")
plt.annotate(line_eq,(6,70),fontsize=15,color="red")
plt.xlabel('Northern Hemisphere Humidity')
plt.ylabel('Northern Hemisphere Latitude')
print(f"The r-squared is: {rvalue**2}")
rsquare_val = round(rvalue**2,2)
print(f"This says the Humidity and Latitude in the Northern Hemisphere as a coorelation of {rsquare_val}% which says there is no coorelation")

plt.show()
# Out:
# The r-squared is: 0.05186921779558368
# This says the Humidity and Latitude in the Northern Hemisphere as a coorelation of 0.05% which says there is no coorelation

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(souhum, soulat)
regress_values = souhum * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(souhum, soulat)
plt.plot(souhum,regress_values,"r-")
plt.annotate(line_eq,(15,-10),fontsize=15,color="red")
plt.xlabel('Southern Hemisphere Humidity')
plt.ylabel('Southern Hemisphere Latitude')
print(f"The r-squared is: {rvalue**2}")
rsquare_val = round(rvalue**2,2)
print(f"This says the Humidity and Latitude in the Southern Hemisphere as a coorelation of {rsquare_val}% which says there is no coorelation")

plt.show()
# Out:
# The r-squared is: 0.1418581220019049
# This says the Humidity and Latitude in the Southern Hemisphere as a coorelation of 0.14% which says there is no coorelation

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(norcloud, norlat)
regress_values = norcloud * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(norcloud, norlat)
plt.plot(norcloud,regress_values,"r-")
plt.annotate(line_eq,(20,70),fontsize=15,color="red")
plt.xlabel('Northern Hemisphere Cloudiness')
plt.ylabel('Northern Hemisphere Latitude')
print(f"The r-squared is: {rvalue**2}")
rsquare_val = round(rvalue**2,2)
print(f"This says the Cloudiness and Latitude in the Northern Hemisphere as a coorelation of {rsquare_val}% which says there is no coorelation")

plt.show()
# Out:
# The r-squared is: 0.06160792188301474
# This says the Cloudiness and Latitude in the Northern Hemisphere as a coorelation of 0.06% which says there is no coorelation

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(soucloud, soulat)
regress_values = soucloud * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(soucloud, soulat)
plt.plot(soucloud,regress_values,"r-")
plt.annotate(line_eq,(40,-40),fontsize=15,color="red")
plt.xlabel('Southern Hemisphere Cloudiness')
plt.ylabel('Southern Hemisphere Latitude')
print(f"The r-squared is: {rvalue**2}")
rsquare_val = round(rvalue**2,2)
print(f"This says the Cloudiness and Latitude in the Southern Hemisphere as a coorelation of {rsquare_val}% which says there is no coorelation")

plt.show()
# Out:
# The r-squared is: 0.1033440497381785
# This says the Cloudiness and Latitude in the Southern Hemisphere as a coorelation of 0.1% which says there is no coorelation

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(norwind, norlat)
regress_values = norwind * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(norwind, norlat)
plt.plot(norwind,regress_values,"r-")
plt.annotate(line_eq,(9,30),fontsize=15,color="red")
plt.xlabel('Northern Hemisphere Wind Speed')
plt.ylabel('Northern Hemisphere Latitude')
print(f"The r-squared is: {rvalue**2}")
rsquare_val = round(rvalue**2,2)
print(f"This says the Wind Speed and Latitude in the Northern Hemisphere as a coorelation of {rsquare_val}% which says there is no coorelation")

plt.show()
# Out:
# The r-squared is: 0.06088807196591188
# This says the Wind Speed and Latitude in the Northern Hemisphere as a coorelation of 0.06% which says there is no coorelation

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(souwind, soulat)
regress_values = souwind * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(souwind, soulat)
plt.plot(souwind,regress_values,"r-")
plt.annotate(line_eq,(5,-50),fontsize=15,color="red")
plt.xlabel('Southern Hemisphere Wind Speed')
plt.ylabel('Southern Hemisphere Latitude')
print(f"The r-squared is: {rvalue**2}")
rsquare_val = round(rvalue**2,2)
print(f"This says the Wind Speed and Latitude in the Southern Hemisphere as a coorelation of {rsquare_val}% which says there is no coorelation")

plt.show()
# Out:
# The r-squared is: 0.13707713526447163
# This says the Wind Speed and Latitude in the Southern Hemisphere as a coorelation of 0.14% which says there is no coorelation

# %%
#outputting file to CSV
summary_city_info_df.to_csv("Output/summarycityinfo.csv", index=False, header=True)
